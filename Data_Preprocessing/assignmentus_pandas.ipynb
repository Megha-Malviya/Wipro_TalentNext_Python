# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("melb_data.csv")

# %%
data.describe(include='all')
# Out:
#           Unnamed: 0     Suburb     Address         Rooms   Type  \
# count   18396.000000      18396       18396  18396.000000  18396
# unique           NaN        330       18134           NaN      3
# top              NaN  Reservoir  14 Rose St           NaN      h
# freq             NaN        541           3           NaN  12095
# mean    11826.787073        NaN         NaN      2.935040    NaN
# std      6800.710448        NaN         NaN      0.958202    NaN
# min         1.000000        NaN         NaN      1.000000    NaN
# 25%      5936.750000        NaN         NaN      2.000000    NaN
# 50%     11820.500000        NaN         NaN      3.000000    NaN
# 75%     17734.250000        NaN         NaN      3.000000    NaN
# max     23546.000000        NaN         NaN     12.000000    NaN
#
#                Price Method SellerG        Date      Distance  ...  \
# count   1.839600e+04  18396   18396       18396  18395.000000  ...
# unique           NaN      5     305          58           NaN  ...
# top              NaN      S  Nelson  27/05/2017           NaN  ...
# freq             NaN  12034    2002         610           NaN  ...
# mean    1.056697e+06    NaN     NaN         NaN     10.389986  ...
# std     6.419217e+05    NaN     NaN         NaN      6.009050  ...
# min     8.500000e+04    NaN     NaN         NaN      0.000000  ...
# 25%     6.330000e+05    NaN     NaN         NaN      6.300000  ...
# 50%     8.800000e+05    NaN     NaN         NaN      9.700000  ...
# 75%     1.302000e+06    NaN     NaN         NaN     13.300000  ...
# max     9.000000e+06    NaN     NaN         NaN     48.100000  ...
#
#             Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count   14925.000000  14820.000000   13603.000000   7762.000000  8958.000000
# unique           NaN           NaN            NaN           NaN          NaN
# top              NaN           NaN            NaN           NaN          NaN
# freq             NaN           NaN            NaN           NaN          NaN
# mean        1.538492      1.615520     558.116371    151.220219  1965.879996
# std         0.689311      0.955916    3987.326586    519.188596    37.013261
# min         0.000000      0.000000       0.000000      0.000000  1196.000000
# 25%         1.000000      1.000000     176.500000     93.000000  1950.000000
# 50%         1.000000      2.000000     440.000000    126.000000  1970.000000
# 75%         2.000000      2.000000     651.000000    174.000000  2000.000000
# max         8.000000     10.000000  433014.000000  44515.000000  2018.000000
#
#         CouncilArea     Lattitude    Longtitude             Regionname  \
# count         12233  15064.000000  15064.000000                  18395
# unique           33           NaN           NaN                      8
# top        Moreland           NaN           NaN  Southern Metropolitan
# freq           1163           NaN           NaN                   6343
# mean            NaN    -37.809849    144.996338                    NaN
# std             NaN      0.081152      0.106375                    NaN
# min             NaN    -38.182550    144.431810                    NaN
# 25%             NaN    -37.858100    144.931193                    NaN
# 50%             NaN    -37.803625    145.000920                    NaN
# 75%             NaN    -37.756270    145.060000                    NaN
# max             NaN    -37.408530    145.526350                    NaN
#
#         Propertycount
# count    18395.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean      7517.975265
# std       4488.416599
# min        249.000000
# 25%       4294.000000
# 50%       6567.000000
# 75%      10331.000000
# max      21650.000000
#
# [11 rows x 22 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          3469
# Bathroom          3471
# Car               3576
# Landsize          4793
# BuildingArea     10634
# YearBuilt         9438
# CouncilArea       6163
# Lattitude         3332
# Longtitude        3332
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
num_cols = data.select_dtypes(include=[np.number]).columns
for col in num_cols:
    data[col] = data[col].fillna(data[col].median())

# %%
cat_cols = data.select_dtypes(include=[object]).columns
for col in cat_cols:
    data[col] = data[col].fillna(data[col].mode()[0])

# %%
data = pd.get_dummies(data, columns=cat_cols, drop_first=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18396 entries, 0 to 18395
# Columns: 18882 entries, Unnamed: 0 to Regionname_Western Victoria
# dtypes: bool(18868), float64(12), int64(2)
# memory usage: 333.0 MB

# %%
data.head()
# Out:
#    Unnamed: 0  Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 0           1      2  1480000.0       2.5    3067.0       2.0       1.0  1.0
# 1           2      2  1035000.0       2.5    3067.0       2.0       1.0  0.0
# 2           4      3  1465000.0       2.5    3067.0       3.0       2.0  0.0
# 3           5      3   850000.0       2.5    3067.0       3.0       2.0  1.0
# 4           6      4  1600000.0       2.5    3067.0       3.0       1.0  2.0
#
#    Landsize  BuildingArea  ...  CouncilArea_Wyndham  CouncilArea_Yarra  \
# 0     202.0         126.0  ...                False               True
# 1     156.0          79.0  ...                False               True
# 2     134.0         150.0  ...                False               True
# 3      94.0         126.0  ...                False               True
# 4     120.0         142.0  ...                False               True
#
#    CouncilArea_Yarra Ranges  Regionname_Eastern Victoria  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
#
#    Regionname_Northern Metropolitan  Regionname_Northern Victoria  \
# 0                              True                         False
# 1                              True                         False
# 2                              True                         False
# 3                              True                         False
# 4                              True                         False
#
#    Regionname_South-Eastern Metropolitan  Regionname_Southern Metropolitan  \
# 0                                  False                             False
# 1                                  False                             False
# 2                                  False                             False
# 3                                  False                             False
# 4                                  False                             False
#
#    Regionname_Western Metropolitan  Regionname_Western Victoria
# 0                            False                        False
# 1                            False                        False
# 2                            False                        False
# 3                            False                        False
# 4                            False                        False
#
# [5 rows x 18882 columns]
