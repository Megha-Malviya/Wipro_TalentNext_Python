# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Mall_Customers.csv")
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
# ...

# %%
df.columns = df.columns.str.strip()

print("Columns in dataset:", df.columns)
if "Gender" in df.columns:
    sns.countplot(x="Gender", data=df, palette="Set2")
    plt.title("Gender Distribution")
    plt.show()
else:
    print("⚠️ 'Gender' column not found! Available columns are:", df.columns)
# Out:
# Columns in dataset: Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
# ⚠️ 'Gender' column not found! Available columns are: Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
if "Age" in df.columns:
    sns.histplot(df["Age"], bins=20, kde=True, color="skyblue")
    plt.title("Age Distribution")
    plt.xlabel("Age")
    plt.ylabel("Frequency")
    plt.show()
else:
    print("⚠️ 'Age' column not found! Available columns are:", df.columns)

# %%
sns.histplot(df["Age"], bins=20, kde=True, color="skyblue")
plt.title("Age Distribution")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
# Rename 'Genre' column to 'Gender' for consistency
if "Genre" in df.columns:
    df.rename(columns={"Genre": "Gender"}, inplace=True)
    print("Column 'Genre' renamed to 'Gender'")
else:
    print("⚠️ 'Genre' column not found! Available columns are:", df.columns)
# Out:
# Column 'Genre' renamed to 'Gender'

# %%
sns.scatterplot(
    x="Age",
    y="Spending Score (1-100)",
    hue="Gender",
    data=df,
    palette="Set1"
)
plt.title("Age vs Spending Score")
plt.xlabel("Age")
plt.ylabel("Spending Score (1-100)")
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
df.columns = df.columns.str.strip()  # remove leading/trailing spaces
print(df.columns.tolist())
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
sns.boxplot(x="Gender", y="Age", data=df, palette="Set3")
plt.title("Age Distribution by Gender")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25340\619303383.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender", y="Age", data=df, palette="Set3")

# %%
sns.boxplot(x="Gender", y="Spending Score (1-100)", data=df, palette="Set2")
plt.title("Spending Score Distribution by Gender")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25340\791015180.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender", y="Spending Score (1-100)", data=df, palette="Set2")

# %%
sns.boxplot(x="Gender", y="Annual Income (k$)", data=df, palette="coolwarm")
plt.title("Annual Income Distribution by Gender")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_25340\852555370.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Gender", y="Annual Income (k$)", data=df, palette="coolwarm")

# %%
# Clean column names (remove spaces & make consistent)
df.columns = df.columns.str.strip()

# Verify column names
print("Cleaned Columns:", df.columns)
# Out:
# Cleaned Columns: Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
